# %%
import numpy as np
import pandas as pd
import datetime as dt

import fastparquet
import snappy

# %matplotlib inline
import curbdata as cd
import importlib

# %%
alldays_timestamped = pd.read_parquet('TimestampToSep11new.parquet')
alldays_timestamped.sort_index(level='Timestamp', inplace=True)

# %%
format_dict = {'unrestricted spaces': ['Space 3'],
              'key spaces': ['Space 1', 'Space 2', 'Space 3', 'SB bike lane'],
              'location column': 'Vehicle Location',
              'violator column': 'Violator',
              'enf start/end': ('18:00', '22:00'),
              }

# %%
importlib.reload(cd);

# %%
sm_curb = cd.CurbDataPlotter(alldays_timestamped, format_dict)

# %%
help(sm_curb)
# Out:
# Help on CurbDataPlotter in module curbdata object:
#
# class CurbDataPlotter(CurbData)
#  |  CurbDataPlotter(timestamped_df, format_dict)
#  |
#  |  Stores curb utilization data and associated functions
#  |
#  |  Method resolution order:
#  |      CurbDataPlotter
#  |      CurbData
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, timestamped_df, format_dict)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __make_palette__(self)
#  |      #DONE more color-blind safe colors to break out TNC/CNS blocking?
#  |      #Also further abstraction concurrent with timestamper improvements.
#  |
#  |  __make_widgets__(self)
#  |
#  |  activity_distribution_plot(self, activity, subset=False)
#  |      Plots a time distribution of CNS or TNC activity
#  |
#  |  interactive_plot(self)
#  |      Using ipython widgets, generates interactive plot enabling plot type and
#  |      subset specification.
#  |
#  |  time_activity_plot(self, percent=True)
#  |      Generate plot aggregating the total number of activities and amount of time
#  |      for each user/violator type in subset interval. Can specify percent=false for
#  |      absolute counts instead of stacked percentage.
#  |
#  |  time_occ_plot(self, save=False)
#  |      Plots space occupancy and bike lane blocking over time in the selected interval.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from CurbData:
#  |
#  |  __time_filter__(self)
#  |      filters df to enforcement interval provided in format (as 24-hr time hh:mm)
#  |
#  |  aggregate_activities(self, percent=False, lz_only=True)
#  |      return counts and total time for each type of activity in subset interval
#  |      also percent blocking, percent viol presence
#  |
#  |  blk_viol_times(self, condition=None)
#  |      returns dict of total times any blocker or violator present in interval
#  |
#  |  blockers_exceed_viol(self)
#  |      Returns a value (in minutes) of the amount of time that the number of blockers
#  |      exceeds the number of violators. A relatively high number may suggest the zone is
#  |      too small
#  |
#  |  conditional(self, condition)
#  |      prints and returns observed conditional of either 'Blocking' or 'Violator
#  |
#  |  download_selection(self, download_all=False)
#  |      Generates downloadable CSV from input df
#  |      Total copy/paste job from
#  |      https://stackoverflow.com/questions/31893930/download-csv-from-an-ipython-notebook
#  |      Javascript allows for client-side CSV generation, avoids creating server-side CSV
#  |      for each request
#  |      Tends to generate two duplicate downloads on Firefox, but one on Safari. Have yet
#  |      to test with Chrome. Likely ipython/Jupyter/browser quirk.
#  |
#  |  span(self)
#  |      Generates df summarizing span of data by date.
#  |      Unlike most methods, includes data outside enforcement interval.
#  |
#  |  subset(self, weekday=None, timestamps=None, verbose=False)
#  |      returns new CurbData object containing specified subset. Can specify as timestamps
#  |      = ('yyyy-mm-dd hh:mm:ss', 'yyyy-mm-dd hh:mm:ss'), or weekday = any day of week,
#  |      Weekdays, Weekends, All Data.
#  |
#  |  violator_timestamp_table(self)
#  |      Generates time-indexed df counting number and type of violators present.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from CurbData:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
times = sm_curb.subset(timestamps=('2019-09-01 18:00:01', '2019-09-01 19:00:01'))

# %%
times.df_subset.head(5)
# Out:
#                      Activity Id  Begin Date  Begin Time    End Time  \
# Timestamp
# 2019-09-01 18:00:02         1338  09/01/2019  5:56:56 PM  6:08:49 PM
# 2019-09-01 18:00:02         1340  09/01/2019  5:59:19 PM  6:00:11 PM
# 2019-09-01 18:00:02         1322  09/01/2019  5:00:00 PM  6:32:42 PM
# 2019-09-01 18:00:02         1321  09/01/2019  5:00:00 PM  6:08:26 PM
# 2019-09-01 18:00:02         1339  09/01/2019  5:58:32 PM  6:01:04 PM
#
#                          Vehicle Location Vehicle Type  \
# Timestamp
# 2019-09-01 18:00:02               Space 2          Car
# 2019-09-01 18:00:02          SB bike lane          Car
# 2019-09-01 18:00:02               Space 3          Car
# 2019-09-01 18:00:02               Space 1          Car
# 2019-09-01 18:00:02  NB right turn pocket          Car
#
#                     Vehicle Characteristics     Transaction Characteristics  \
# Timestamp
# 2019-09-01 18:00:02                    None  Interaction with parking meter
# 2019-09-01 18:00:02             Blinkers on                            None
# 2019-09-01 18:00:02                    None                            None
# 2019-09-01 18:00:02                    None  Interaction with parking meter
# 2019-09-01 18:00:02             Blinkers on                            None
#
#                      Bikeway Users Displaced  LZ Space Avail  \
# Timestamp
# 2019-09-01 18:00:02                      NaN             NaN
# 2019-09-01 18:00:02                      0.0             0.0
# 2019-09-01 18:00:02                      NaN             NaN
# 2019-09-01 18:00:02                      NaN             NaN
# 2019-09-01 18:00:02                      NaN             0.0
#
#                      Occupied while idle?   CNS?   TNC?  \
# Timestamp
# 2019-09-01 18:00:02                 False   True  False
# 2019-09-01 18:00:02                 False   True  False
# 2019-09-01 18:00:02                 False  False  False
# 2019-09-01 18:00:02                 False  False  False
# 2019-09-01 18:00:02                  True  False  False
#
#                                                              Notes Duration  \
# Timestamp
# 2019-09-01 18:00:02  looked at the meter but still decided to park  0:11:53
# 2019-09-01 18:00:02                                           None  0:00:52
# 2019-09-01 18:00:02                                           None  1:32:42
# 2019-09-01 18:00:02                                           None  1:08:26
# 2019-09-01 18:00:02                                           None  0:02:32
#
#                                      Violator
# Timestamp
# 2019-09-01 18:00:02  Likely Non-Violator, CNS
# 2019-09-01 18:00:02   Bike Lane Blocking, CNS
# 2019-09-01 18:00:02       Likely Non-Violator
# 2019-09-01 18:00:02       Likely Non-Violator
# 2019-09-01 18:00:02       Likely Non-Violator

# %%
times.violator_timestamp_table().head(5)
# Out:
#                      Likely Non-Violator, CNS  Bike Lane Blocking, CNS  \
# Timestamp
# 2019-09-01 18:00:02                       2.0                      1.0
# 2019-09-01 18:00:03                       2.0                      1.0
# 2019-09-01 18:00:04                       2.0                      1.0
# 2019-09-01 18:00:05                       2.0                      1.0
# 2019-09-01 18:00:06                       2.0                      1.0
#
#                      Likely Non-Violator  Bike Lane Blocking, TNC  \
# Timestamp
# 2019-09-01 18:00:02                  2.0                      NaN
# 2019-09-01 18:00:03                  2.0                      NaN
# 2019-09-01 18:00:04                  2.0                      NaN
# 2019-09-01 18:00:05                  2.0                      NaN
# 2019-09-01 18:00:06                  2.0                      NaN
#
#                      Bike Lane Blocking  Likely Non-Violator, TNC  Violator  \
# Timestamp
# 2019-09-01 18:00:02                 NaN                       NaN       NaN
# 2019-09-01 18:00:03                 NaN                       NaN       NaN
# 2019-09-01 18:00:04                 NaN                       NaN       NaN
# 2019-09-01 18:00:05                 NaN                       NaN       NaN
# 2019-09-01 18:00:06                 NaN                       NaN       NaN
#
#                      Total Violators  Total Blockers  Blockers Less Violators  \
# Timestamp
# 2019-09-01 18:00:02              0.0             1.0                      1.0
# 2019-09-01 18:00:03              0.0             1.0                      1.0
# 2019-09-01 18:00:04              0.0             1.0                      1.0
# 2019-09-01 18:00:05              0.0             1.0                      1.0
# 2019-09-01 18:00:06              0.0             1.0                      1.0
#
#                      Any Violator  Any Blocking
# Timestamp
# 2019-09-01 18:00:02             0             1
# 2019-09-01 18:00:03             0             1
# 2019-09-01 18:00:04             0             1
# 2019-09-01 18:00:05             0             1
# 2019-09-01 18:00:06             0             1

# %%
times.blockers_exceed_viol()
# Out:
# {'blockers_exceed': 7.833333333333333, 'total_minutes': 59.96666666666667}

# %%
times.conditional('Violator')
# Out:
# Out of the 43 minutes that at least one violator was parked in the loading zone, the bike lane was blocked for 13 minutes (30 % of the time!)
# {'block_sec': 804.0, 'block_min': 13, 'viol_sec': 2634.0, 'viol_min': 43}

# %%
times.conditional('Blocking')
# Out:
# Out of the 21 minutes the bike lane was blocked in the study period, at least one violator was parked in the loading zone for 13 minutes (61 % of the time!)
# {'block_sec': 1274.0, 'block_min': 21, 'viol_sec': 804.0, 'viol_min': 13}

# %%
mondays = sm_curb.subset(weekday='Monday')

# %%
mondays.conditional('Violator')
# Out:
# Out of the 555 minutes that at least one violator was parked in the loading zone, the bike lane was blocked for 66 minutes (11 % of the time!)
# {'block_sec': 3965.0, 'block_min': 66, 'viol_sec': 33343.0, 'viol_min': 555}

# %%
mondays.blockers_exceed_viol()
# Out:
# {'blockers_exceed': 24.866666666666667, 'total_minutes': 239.96666666666667}

# %%
times.blockers_exceed_viol()
# Out:
# {'blockers_exceed': 7.833333333333333, 'total_minutes': 59.96666666666667}

# %%
mondays.aggregate_activities()
# Out:
#                               Total Time  Activity Count  \
# Violator Classification
# Bike Lane Blocking       0 days 00:09:50              10
# Bike Lane Blocking, CNS  0 days 01:16:39              20
# Bike Lane Blocking, TNC  0 days 00:12:41              23
# Likely Non-Violator      0 days 01:33:13              33
# Likely Non-Violator, CNS 0 days 04:22:41              41
# Likely Non-Violator, TNC 0 days 00:24:07              16
# Violator                 0 days 14:42:04              12
# Violator, CNS            0 days 00:15:04               1
#
#                           Bikeway Users Displaced
# Violator Classification
# Bike Lane Blocking                            4.0
# Bike Lane Blocking, CNS                      17.0
# Bike Lane Blocking, TNC                       7.0
# Likely Non-Violator                           0.0
# Likely Non-Violator, CNS                      0.0
# Likely Non-Violator, TNC                      0.0
# Violator                                      0.0
# Violator, CNS                                 0.0

# %%
times.aggregate_activities()
# Out:
#                               Total Time  Activity Count  \
# Violator Classification
# Bike Lane Blocking       0 days 00:04:41               3
# Bike Lane Blocking, CNS  0 days 00:18:35               6
# Bike Lane Blocking, TNC  0 days 00:01:28               5
# Likely Non-Violator      0 days 00:12:19               3
# Likely Non-Violator, CNS 0 days 00:32:19               7
# Likely Non-Violator, TNC 0 days 00:00:37               2
# Violator                 0 days 01:20:12               2
#
#                           Bikeway Users Displaced
# Violator Classification
# Bike Lane Blocking                            6.0
# Bike Lane Blocking, CNS                       9.0
# Bike Lane Blocking, TNC                       1.0
# Likely Non-Violator                           0.0
# Likely Non-Violator, CNS                      0.0
# Likely Non-Violator, TNC                      0.0
# Violator                                      0.0

# %%
times.aggregate_activities(percent=True)
# Out:
#                           Percent Time Percent Activities  \
# Violator Classification
# Bike Lane Blocking            0.031184           0.107143
# Bike Lane Blocking, CNS       0.123738           0.214286
# Bike Lane Blocking, TNC       0.009766           0.178571
# Likely Non-Violator           0.082011           0.107143
# Likely Non-Violator, CNS      0.215181               0.25
# Likely Non-Violator, TNC      0.004106          0.0714286
# Violator                      0.534014          0.0714286
#
#                          Percent Bikeway Users Displaced
# Violator Classification
# Bike Lane Blocking                                 0.375
# Bike Lane Blocking, CNS                           0.5625
# Bike Lane Blocking, TNC                           0.0625
# Likely Non-Violator                                    0
# Likely Non-Violator, CNS                               0
# Likely Non-Violator, TNC                               0
# Violator                                               0

# %%
sm_curb.span()
# Out:
#                 date start time  end time        duration
# 0   Wed, Aug 21 2019   12:00:00  22:15:40 0 days 10:15:40
# 1   Thu, Aug 22 2019   12:00:00  22:29:31 0 days 10:29:31
# 2   Fri, Aug 23 2019   12:00:00  22:28:30 0 days 10:28:30
# 3   Sat, Aug 24 2019   12:00:00  22:25:15 0 days 10:25:15
# 4   Sun, Aug 25 2019   12:00:00  22:26:14 0 days 10:26:14
# 5   Mon, Aug 26 2019   12:00:00  22:27:58 0 days 10:27:58
# 6   Tue, Aug 27 2019   12:00:00  22:29:20 0 days 10:29:20
# 7   Wed, Aug 28 2019   12:00:00  13:36:36 0 days 01:36:36
# 8   Thu, Aug 29 2019   17:00:00  22:28:53 0 days 05:28:53
# 9   Fri, Aug 30 2019   17:00:00  22:27:31 0 days 05:27:31
# 10  Sat, Aug 31 2019   17:00:00  22:22:43 0 days 05:22:43
# 11  Sun, Sep 01 2019   17:00:00  21:58:56 0 days 04:58:56
# 12  Mon, Sep 02 2019   17:00:00  22:03:53 0 days 05:03:53
# 13  Tue, Sep 03 2019   17:00:00  22:04:07 0 days 05:04:07
# 14  Wed, Sep 04 2019   17:00:00  22:10:41 0 days 05:10:41
# 15  Thu, Sep 05 2019   17:00:00  22:13:16 0 days 05:13:16
# 16  Fri, Sep 06 2019   17:00:00  22:24:03 0 days 05:24:03
# 17  Sat, Sep 07 2019   17:00:00  22:16:47 0 days 05:16:47
# 18  Sun, Sep 08 2019   17:00:00  22:26:33 0 days 05:26:33
# 19  Mon, Sep 09 2019   17:00:00  22:10:59 0 days 05:10:59
# 20  Tue, Sep 10 2019   17:00:00  22:26:51 0 days 05:26:51
# 21  Wed, Sep 11 2019   17:00:00  17:18:54 0 days 00:18:54

# %%
sm_curb.span()['duration'].sum()
# Out:
# Timedelta('5 days 23:33:11')

# %%
24*5 + 23
# Out:
# 143

# %%
sm_curb.violator_timestamp_table()
# Out:
#                      Likely Non-Violator  Likely Non-Violator, CNS  Violator  \
# Timestamp
# 2019-08-21 18:00:30                  1.0                       NaN       NaN
# 2019-08-21 18:00:31                  1.0                       NaN       NaN
# 2019-08-21 18:00:32                  1.0                       NaN       NaN
# 2019-08-21 18:00:33                  1.0                       NaN       NaN
# 2019-08-21 18:00:34                  1.0                       NaN       NaN
# ...                                  ...                       ...       ...
# 2019-09-10 21:56:46                  NaN                       NaN       NaN
# 2019-09-10 21:56:47                  NaN                       NaN       NaN
# 2019-09-10 21:56:48                  NaN                       NaN       NaN
# 2019-09-10 21:56:49                  NaN                       NaN       NaN
# 2019-09-10 21:56:50                  NaN                       NaN       NaN
#
#                      Bike Lane Blocking  Bike Lane Blocking, TNC  \
# Timestamp
# 2019-08-21 18:00:30                 NaN                      NaN
# 2019-08-21 18:00:31                 NaN                      NaN
# 2019-08-21 18:00:32                 NaN                      NaN
# 2019-08-21 18:00:33                 NaN                      NaN
# 2019-08-21 18:00:34                 NaN                      NaN
# ...                                 ...                      ...
# 2019-09-10 21:56:46                 NaN                      NaN
# 2019-09-10 21:56:47                 NaN                      NaN
# 2019-09-10 21:56:48                 NaN                      NaN
# 2019-09-10 21:56:49                 NaN                      NaN
# 2019-09-10 21:56:50                 NaN                      NaN
#
#                      Bike Lane Blocking, CNS  Likely Non-Violator, TNC  \
# Timestamp
# 2019-08-21 18:00:30                      NaN                       NaN
# 2019-08-21 18:00:31                      NaN                       NaN
# 2019-08-21 18:00:32                      NaN                       NaN
# 2019-08-21 18:00:33                      NaN                       NaN
# 2019-08-21 18:00:34                      NaN                       NaN
# ...                                      ...                       ...
# 2019-09-10 21:56:46                      NaN                       1.0
# 2019-09-10 21:56:47                      NaN                       1.0
# 2019-09-10 21:56:48                      NaN                       1.0
# 2019-09-10 21:56:49                      NaN                       1.0
# 2019-09-10 21:56:50                      NaN                       1.0
#
#                      Violator, CNS  Total Violators  Total Blockers  \
# Timestamp
# 2019-08-21 18:00:30            NaN              0.0             0.0
# 2019-08-21 18:00:31            NaN              0.0             0.0
# 2019-08-21 18:00:32            NaN              0.0             0.0
# 2019-08-21 18:00:33            NaN              0.0             0.0
# 2019-08-21 18:00:34            NaN              0.0             0.0
# ...                            ...              ...             ...
# 2019-09-10 21:56:46            NaN              0.0             0.0
# 2019-09-10 21:56:47            NaN              0.0             0.0
# 2019-09-10 21:56:48            NaN              0.0             0.0
# 2019-09-10 21:56:49            NaN              0.0             0.0
# 2019-09-10 21:56:50            NaN              0.0             0.0
#
#                      Blockers Less Violators  Any Violator  Any Blocking
# Timestamp
# 2019-08-21 18:00:30                      0.0             0             0
# 2019-08-21 18:00:31                      0.0             0             0
# 2019-08-21 18:00:32                      0.0             0             0
# 2019-08-21 18:00:33                      0.0             0             0
# 2019-08-21 18:00:34                      0.0             0             0
# ...                                      ...           ...           ...
# 2019-09-10 21:56:46                      0.0             0             0
# 2019-09-10 21:56:47                      0.0             0             0
# 2019-09-10 21:56:48                      0.0             0             0
# 2019-09-10 21:56:49                      0.0             0             0
# 2019-09-10 21:56:50                      0.0             0             0
#
# [273004 rows x 13 columns]

# %%
sm_curb.df_all
# Out:
#                      Activity Id  Begin Date   Begin Time     End Time  \
# Timestamp
# 2019-08-21 12:00:00           16  08/21/2019  12:00:00 PM  12:04:51 PM
# 2019-08-21 12:00:01           16  08/21/2019  12:00:00 PM  12:04:51 PM
# 2019-08-21 12:00:02           16  08/21/2019  12:00:00 PM  12:04:51 PM
# 2019-08-21 12:00:03           16  08/21/2019  12:00:00 PM  12:04:51 PM
# 2019-08-21 12:00:04           16  08/21/2019  12:00:00 PM  12:04:51 PM
# ...                          ...         ...          ...          ...
# 2019-09-11 17:19:59         2255  09/11/2019   5:00:00 PM   5:20:00 PM
# 2019-09-11 17:19:59         2257  09/11/2019   5:18:54 PM   5:20:00 PM
# 2019-09-11 17:20:00         2254  09/11/2019   5:00:00 PM   5:20:00 PM
# 2019-09-11 17:20:00         2255  09/11/2019   5:00:00 PM   5:20:00 PM
# 2019-09-11 17:20:00         2257  09/11/2019   5:18:54 PM   5:20:00 PM
#
#                     Vehicle Location Vehicle Type  \
# Timestamp
# 2019-08-21 12:00:00          Space 3          Car
# 2019-08-21 12:00:01          Space 3          Car
# 2019-08-21 12:00:02          Space 3          Car
# 2019-08-21 12:00:03          Space 3          Car
# 2019-08-21 12:00:04          Space 3          Car
# ...                              ...          ...
# 2019-09-11 17:19:59          Space 3          Car
# 2019-09-11 17:19:59          Space 1          Car
# 2019-09-11 17:20:00          Space 2          Car
# 2019-09-11 17:20:00          Space 3          Car
# 2019-09-11 17:20:00          Space 1          Car
#
#                                          Vehicle Characteristics  \
# Timestamp
# 2019-08-21 12:00:00  Other significant characteristic (see note)
# 2019-08-21 12:00:01  Other significant characteristic (see note)
# 2019-08-21 12:00:02  Other significant characteristic (see note)
# 2019-08-21 12:00:03  Other significant characteristic (see note)
# 2019-08-21 12:00:04  Other significant characteristic (see note)
# ...                                                          ...
# 2019-09-11 17:19:59                                         None
# 2019-09-11 17:19:59                                         None
# 2019-09-11 17:20:00                                         None
# 2019-09-11 17:20:00                                         None
# 2019-09-11 17:20:00                                         None
#
#                         Transaction Characteristics  Bikeway Users Displaced  \
# Timestamp
# 2019-08-21 12:00:00                            None                      NaN
# 2019-08-21 12:00:01                            None                      NaN
# 2019-08-21 12:00:02                            None                      NaN
# 2019-08-21 12:00:03                            None                      NaN
# 2019-08-21 12:00:04                            None                      NaN
# ...                                             ...                      ...
# 2019-09-11 17:19:59                            None                      NaN
# 2019-09-11 17:19:59  Interaction with parking meter                      NaN
# 2019-09-11 17:20:00  Interaction with parking meter                      NaN
# 2019-09-11 17:20:00                            None                      NaN
# 2019-09-11 17:20:00  Interaction with parking meter                      NaN
#
#                      LZ Space Avail  Occupied while idle?   CNS?   TNC?  \
# Timestamp
# 2019-08-21 12:00:00             NaN                 False   True  False
# 2019-08-21 12:00:01             NaN                 False   True  False
# 2019-08-21 12:00:02             NaN                 False   True  False
# 2019-08-21 12:00:03             NaN                 False   True  False
# 2019-08-21 12:00:04             NaN                 False   True  False
# ...                             ...                   ...    ...    ...
# 2019-09-11 17:19:59             NaN                 False  False  False
# 2019-09-11 17:19:59             NaN                 False  False  False
# 2019-09-11 17:20:00             NaN                 False  False  False
# 2019-09-11 17:20:00             NaN                 False  False  False
# 2019-09-11 17:20:00             NaN                 False  False  False
#
#                                                     Notes Duration  \
# Timestamp
# 2019-08-21 12:00:00  person returns with two plastic bags  0:04:51
# 2019-08-21 12:00:01  person returns with two plastic bags  0:04:51
# 2019-08-21 12:00:02  person returns with two plastic bags  0:04:51
# 2019-08-21 12:00:03  person returns with two plastic bags  0:04:51
# 2019-08-21 12:00:04  person returns with two plastic bags  0:04:51
# ...                                                   ...      ...
# 2019-09-11 17:19:59                                  None  0:20:00
# 2019-09-11 17:19:59                                  None  0:01:06
# 2019-09-11 17:20:00                                  None  0:20:00
# 2019-09-11 17:20:00                                  None  0:20:00
# 2019-09-11 17:20:00                                  None  0:01:06
#
#                                      Violator
# Timestamp
# 2019-08-21 12:00:00  Likely Non-Violator, CNS
# 2019-08-21 12:00:01  Likely Non-Violator, CNS
# 2019-08-21 12:00:02  Likely Non-Violator, CNS
# 2019-08-21 12:00:03  Likely Non-Violator, CNS
# 2019-08-21 12:00:04  Likely Non-Violator, CNS
# ...                                       ...
# 2019-09-11 17:19:59       Likely Non-Violator
# 2019-09-11 17:19:59       Likely Non-Violator
# 2019-09-11 17:20:00       Likely Non-Violator
# 2019-09-11 17:20:00       Likely Non-Violator
# 2019-09-11 17:20:00       Likely Non-Violator
#
# [1581475 rows x 16 columns]

# %%
sm_curb.activity_distribution_plot('TNC')

# %%
sm_curb.activity_distribution_plot('CNS')

# %%
times.time_occ_plot();

# %%
times.time_activity_plot();

# %%
times.time_activity_plot(percent=False);

# %%
mondays.time_activity_plot();

# %%
mondays.time_activity_plot(percent=False);
